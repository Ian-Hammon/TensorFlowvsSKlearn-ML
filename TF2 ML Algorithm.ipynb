# %% [markdown]
# # Minimal example with TensorFlow 2.0

# %% [markdown]
# Create a machine learning algorithm with TensorFlow version 2.19.0

# %% [markdown]
# ### Import the Relevant Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ### Data generation

# %%
observations = 1000

xs = np.random.uniform(low=-10, high=10, size = (observations,1))
zs = np.random.uniform(-10,10,(observations,1))

generated_inputs = np.column_stack((xs,zs))
noise = np.random.uniform(-1,1,(observations,1))
generated_targets = 2*xs - 3*zs + 5 + noise
np.savez('TF_intro', inputs=generated_inputs, targets=generated_targets) #This will save a .npz file in your Jupyter notebook for use later on.

# %% [markdown]
# ### Solving with TensorFlow

# %%
training_data = np.load('TF_intro.npz')

# %%
input_size = 2
output_size = 1

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size)
                            ])

model.compile(optimizer='sgd',loss='mean_squared_error') # SGD = Stochastic Gradient Descent
model.fit(training_data['inputs'], training_data['targets'], epochs=100, verbose=2) #epochs are iterations in TensorFlow. Verbose determines display '0' means silent.
# Out:
# Epoch 1/100
# 32/32 - 0s - 14ms/step - loss: 31.8280
# Epoch 2/100
# 32/32 - 0s - 2ms/step - loss: 4.6259
# Epoch 3/100
# 32/32 - 0s - 2ms/step - loss: 1.5224
# Epoch 4/100
# 32/32 - 0s - 2ms/step - loss: 0.6675
# Epoch 5/100
# 32/32 - 0s - 2ms/step - loss: 0.4392
# Epoch 6/100
# 32/32 - 0s - 2ms/step - loss: 0.3695
# Epoch 7/100
# 32/32 - 0s - 2ms/step - loss: 0.3501
# Epoch 8/100
# 32/32 - 0s - 2ms/step - loss: 0.3422
# Epoch 9/100
# 32/32 - 0s - 2ms/step - loss: 0.3427
# Epoch 10/100
# 32/32 - 0s - 2ms/step - loss: 0.3378
# Epoch 11/100
# 32/32 - 0s - 2ms/step - loss: 0.3393
# Epoch 12/100
# 32/32 - 0s - 2ms/step - loss: 0.3424
# Epoch 13/100
# 32/32 - 0s - 2ms/step - loss: 0.3461
# Epoch 14/100
# 32/32 - 0s - 2ms/step - loss: 0.3448
# Epoch 15/100
# 32/32 - 0s - 2ms/step - loss: 0.3408
# Epoch 16/100
# 32/32 - 0s - 2ms/step - loss: 0.3427
# Epoch 17/100
# 32/32 - 0s - 2ms/step - loss: 0.3473
# Epoch 18/100
# 32/32 - 0s - 2ms/step - loss: 0.3417
# Epoch 19/100
# ...

# %% [markdown]
# ### Extract the weights and biases

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 1.9831772],
#         [-3.0395088]], dtype=float32),
#  array([5.0130053], dtype=float32)]

# %%
weights = model.layers[0].get_weights()[0]
weights
# Out:
# array([[ 1.9831772],
#        [-3.0395088]], dtype=float32)

# %%
bias = model.layers[0].get_weights()[1]
bias
# Out:
# array([5.0130053], dtype=float32)

# %% [markdown]
# ### Extract the ouputs (make predictions)

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[  6.8],
#        [-19.3],
#        [ 11.9],
#        [ 45.2],
#        [-36.9],
#        [  9. ],
#        [ 20.1],
#        [ 32.7],
#        [ 18.3],
#        [ 13.4],
#        [-17.5],
#        [ -0.5],
#        [-20.7],
#        [  9.1],
#        [  3.5],
#        [ 30.4],
#        [-37.4],
#        [ 34.3],
#        [-21.6],
#        [ 21.8],
#        [-35.4],
#        [  9. ],
#        [ -4.7],
#        [ 49.6],
#        [ -3.7],
#        [  1.9],
#        [ 14. ],
#        [ 36.9],
#        [-28. ],
#        [  1. ],
#        [ 19.2],
#        [-41.1],
#        [-10.9],
#        [-21.3],
#        [ 14.1],
#        [ 36.5],
#        [ 37.1],
#        [ -6.7],
#        [ 43.4],
#        [  6.4],
#        [  8.7],
#        [ 16.3],
#        [-13.3],
#        [ -5. ],
#        [  2.3],
#        [ 16.1],
#        [ 19.4],
#        [-12.1],
#        [ 41.7],
#        [ 32.8],
#        [-23.8],
#        [ -5.1],
#        [ -7. ],
#        [-20.9],
#        [ 24. ],
# ...

# %%
training_data['targets'].round(1)
# Out:
# array([[  6. ],
#        [-19. ],
#        [ 11.8],
#        [ 45.3],
#        [-37. ],
#        [  8.5],
#        [ 20.2],
#        [ 32.5],
#        [ 17.8],
#        [ 13.3],
#        [-16.9],
#        [  0.5],
#        [-20.2],
#        [  8.5],
#        [  3.5],
#        [ 31. ],
#        [-37.4],
#        [ 33.3],
#        [-21.4],
#        [ 21.5],
#        [-35.7],
#        [  8.1],
#        [ -3.8],
#        [ 49.1],
#        [ -4. ],
#        [  2.1],
#        [ 13.9],
#        [ 36.4],
#        [-27. ],
#        [  0.4],
#        [ 18.4],
#        [-41.3],
#        [ -9.8],
#        [-21.8],
#        [ 15. ],
#        [ 36.2],
#        [ 36.8],
#        [ -6.8],
#        [ 43. ],
#        [  7.7],
#        [  8.4],
#        [ 16.7],
#        [-14.2],
#        [ -5.3],
#        [  2.2],
#        [ 16.6],
#        [ 20.3],
#        [-12.4],
#        [ 41.5],
#        [ 32.8],
#        [-22.7],
#        [ -5.2],
#        [ -6.8],
#        [-20.3],
#        [ 23.1],
# ...

# %% [markdown]
# ### Plotting the Data

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),np.squeeze(training_data['targets']))
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
